# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthik126/ML-Project/blob/master/ML_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.Name.unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.drop('Name',axis=1,inplace=True)
df.drop('PassengerId',axis=1,inplace=True)
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  ...  Parch            Ticket     Fare  Embarked
# 0           0       3    male  22.0  ...      0         A/5 21171   7.2500         S
# 1           1       1  female  38.0  ...      0          PC 17599  71.2833         C
# 2           1       3  female  26.0  ...      0  STON/O2. 3101282   7.9250         S
# 3           1       1  female  35.0  ...      0            113803  53.1000         S
# 4           0       3    male  35.0  ...      0            373450   8.0500         S
# ..        ...     ...     ...   ...  ...    ...               ...      ...       ...
# 886         0       2    male  27.0  ...      0            211536  13.0000         S
# 887         1       1  female  19.0  ...      0            112053  30.0000         S
# 888         0       3  female   NaN  ...      2        W./C. 6607  23.4500         S
# 889         1       1    male  26.0  ...      0            111369  30.0000         C
# ...

# %%
df.isnull()
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch  Ticket   Fare  Embarked
# 0       False   False  False  False  False  False   False  False     False
# 1       False   False  False  False  False  False   False  False     False
# 2       False   False  False  False  False  False   False  False     False
# 3       False   False  False  False  False  False   False  False     False
# 4       False   False  False  False  False  False   False  False     False
# ..        ...     ...    ...    ...    ...    ...     ...    ...       ...
# 886     False   False  False  False  False  False   False  False     False
# 887     False   False  False  False  False  False   False  False     False
# 888     False   False  False   True  False  False   False  False     False
# 889     False   False  False  False  False  False   False  False     False
# 890     False   False  False  False  False  False   False  False     False
#
# [891 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
import numpy as np
data=np.unique(df['Pclass'])
data
# Out:
# array([1, 2, 3])

# %%
data,data_counts=np.unique(df['Pclass'],return_counts=True)
print(f"The number of people in first class are {data_counts[0]}")
print(f"The number of people in second class are {data_counts[1]}")
print(f"The number of people in third class are {data_counts[2]}")
# Out:
# The number of people in first class are 216
# The number of people in second class are 184
# The number of people in third class are 491

# %%
print(data)
print(data_counts)
# Out:
# [1 2 3]
# [216 184 491]

# %%
#Missing values in Age
age=df['Age']
age.isnull().sum()
# Out:
# 177

# %%
#Percentage of missing values
per=(age.isnull().sum()/len(df)*1.0)*100
per
# Out:
# 19.865319865319865

# %%
df.groupby('Survived').mean()
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
#Missing values in embarked
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.Embarked.isnull().sum()
# Out:
# 2

# %%
#Remove Null Values
df.Embarked.fillna('C',inplace=True)
df.Embarked.isnull().sum()
# Out:
# 0

# %%
clg=df.groupby('Survived').mean()
clg
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
import matplotlib.pyplot as plt
clg['Age'].plot.bar(color='#1e23b0')
plt.ylabel('Age')
plt.show()

# %%
import matplotlib.pyplot as plt
clg['Pclass'].plot.bar(color='#2ce647')
plt.ylabel('Class')
plt.show()

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  ...  Parch            Ticket     Fare  Embarked
# 0           0       3    male  22.0  ...      0         A/5 21171   7.2500         S
# 1           1       1  female  38.0  ...      0          PC 17599  71.2833         C
# 2           1       3  female  26.0  ...      0  STON/O2. 3101282   7.9250         S
# 3           1       1  female  35.0  ...      0            113803  53.1000         S
# 4           0       3    male  35.0  ...      0            373450   8.0500         S
# ..        ...     ...     ...   ...  ...    ...               ...      ...       ...
# 886         0       2    male  27.0  ...      0            211536  13.0000         S
# 887         1       1  female  19.0  ...      0            112053  30.0000         S
# 888         0       3  female   NaN  ...      2        W./C. 6607  23.4500         S
# 889         1       1    male  26.0  ...      0            111369  30.0000         C
# ...

# %%
age=df.groupby('Age').sum()
age
# Out:
#        Survived  Pclass  SibSp  Parch      Fare
# Age
# 0.42          1       3      0      1    8.5167
# 0.67          1       2      1      1   14.5000
# 0.75          2       6      4      2   38.5166
# 0.83          2       4      1      3   47.7500
# 0.92          1       1      1      2  151.5500
# ...         ...     ...    ...    ...       ...
# 70.00         0       3      1      1   81.5000
# 70.50         0       3      0      0    7.7500
# 71.00         0       2      0      0   84.1584
# 74.00         0       3      0      0    7.7750
# 80.00         1       1      0      0   30.0000
#
# [88 rows x 5 columns]

# %%
age['SibSp'].plot.area(color='#0af7e4')
plt.ylabel('Sibling\Spouse')
plt.show()

# %%
age['Survived'].plot.line(color='#faa20a')
plt.ylabel('Survived')
plt.show()

# %%
un,un_counts=np.unique(df['Survived'],return_counts=True)
print(un)
print(un_counts)
# Out:
# [0 1]
# [549 342]

# %%
cp=df.groupby(['Fare','Embarked']).mean()
cp
# Out:
#                    Survived    Pclass        Age  SibSp     Parch
# Fare     Embarked
# 0.0000   S         0.066667  1.933333  35.142857   0.00  0.000000
# 4.0125   C         0.000000  3.000000  20.000000   0.00  0.000000
# 5.0000   S         0.000000  1.000000  33.000000   0.00  0.000000
# 6.2375   S         0.000000  3.000000  61.000000   0.00  0.000000
# 6.4375   C         0.000000  3.000000  34.500000   0.00  0.000000
# ...                     ...       ...        ...    ...       ...
# 227.5250 C         0.750000  1.000000  32.666667   0.25  0.000000
# 247.5208 C         0.500000  1.000000  37.000000   0.00  1.000000
# 262.3750 C         1.000000  1.000000  19.500000   2.00  2.000000
# 263.0000 S         0.500000  1.000000  32.500000   2.50  2.500000
# 512.3292 C         1.000000  1.000000  35.333333   0.00  0.333333
#
# [260 rows x 5 columns]

# %%
cd=df.groupby('Parch').mean()
cd
# Out:
#        Survived    Pclass        Age     SibSp       Fare
# Parch
# 0      0.343658  2.321534  32.178503  0.237463  25.586774
# 1      0.550847  2.203390  24.422000  1.084746  46.778180
# 2      0.500000  2.275000  17.216912  2.062500  64.337604
# 3      0.600000  2.600000  33.200000  1.000000  25.951660
# 4      0.000000  2.500000  44.500000  0.750000  84.968750
# 5      0.200000  3.000000  39.200000  0.600000  32.550000
# 6      0.000000  3.000000  43.000000  1.000000  46.900000

# %%
cs=df.groupby(['Age','Parch']).sum()
cs
# Out:
#              Survived  Pclass  SibSp     Fare
# Age   Parch
# 0.42  1             1       3      0   8.5167
# 0.67  1             1       2      1  14.5000
# 0.75  1             2       6      4  38.5166
# 0.83  1             1       2      1  18.7500
#       2             1       2      0  29.0000
# ...               ...     ...    ...      ...
# 70.00 1             0       1      1  71.0000
# 70.50 0             0       3      0   7.7500
# 71.00 0             0       2      0  84.1584
# 74.00 0             0       3      0   7.7750
# 80.00 0             1       1      0  30.0000
#
# [176 rows x 4 columns]

# %%
cs['SibSp'].plot.line(color='r')
plt.ylabel('Siblings\Spouse')
plt.show()

# %%
df.Fare.isnull().sum()
# Out:
# 0

# %%
df.Ticket.isnull().sum()
# Out:
# 0

# %%
df.drop('Ticket',axis=1,inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
cn=df.groupby(['Embarked','Sex']).mean()
cn
# Out:
#                  Survived    Pclass        Age     SibSp     Parch       Fare
# Embarked Sex
# C        female  0.880000  1.706667  29.031746  0.533333  0.480000  75.298611
#          male    0.305263  2.010526  32.998841  0.263158  0.263158  48.262109
# Q        female  0.750000  2.888889  24.291667  0.222222  0.222222  12.634958
#          male    0.073171  2.926829  30.937500  0.609756  0.121951  13.838922
# S        female  0.689655  2.197044  27.771505  0.837438  0.788177  38.740929
#          male    0.174603  2.421769  30.291440  0.448980  0.240363  21.711996

# %%
cn['Age'].plot.line(color='#eb2fde')
plt.ylabel('Age')
plt.show()

# %%
data1=df.groupby(['SibSp','Pclass']).mean()
data1
# Out:
#               Survived        Age     Parch        Fare
# SibSp Pclass
# 0     1       0.562044  39.181416  0.270073   75.223356
#       2       0.416667  31.934220  0.200000   15.532327
#       3       0.236467  27.630201  0.148148    9.832689
# 1     1       0.746479  37.414154  0.422535   88.492021
#       2       0.581818  27.363636  0.709091   28.385682
#       3       0.325301  24.912698  0.819277   16.658487
# 2     1       0.800000  37.200000  0.800000  159.975840
#       2       0.500000  19.125000  0.875000   44.468750
#       3       0.333333  18.875000  0.466667   19.564993
# 3     1       0.666667  22.000000  2.000000  263.000000
#       2       1.000000  30.000000  0.000000   21.000000
#       3       0.083333   8.875000  1.250000   24.378483
# 4     3       0.166667   7.055556  1.500000   31.855556
# 5     3       0.000000  10.200000  2.000000   46.900000
# 8     3       0.000000        NaN  2.000000   69.550000

# %%
data1['Parch'].plot.line(color='#0c80ed')
plt.ylabel('Parch')
plt.show()
